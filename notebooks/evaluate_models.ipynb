# %% [markdown]
# # Practical Machine Learning and Deep Learning - Assignment 1 - Text De-toxification
#
# ## Task description
#
# Text Detoxification Task is a process of transforming the text with toxic style into the text with the same meaning but with neutral style.
#
# > Formal definition of text detoxification task can be found in [Text Detoxification using Large Pre-trained Neural Models by Dale et al., page 14](https://arxiv.org/abs/2109.08914)
#
# Your assignment is to create a solution for detoxing text with high level of toxicity. It can be a model or set of models, or any algorithm that would work.
#
# ## Data Labeling
#
# Level of Toxicity is labeled with annotating binary classification by people. Text is passed to annotators for them to put specific label toxic/non-toxic. Then number of positive / toxic assesments are divided by the total number of annotators. This process is performed for every entry in the data, resulting in toxicity dataset.
#
# By this process, we have text with toxicity level. However, for training the model it is best to have sample with high toxicity level and its paraphrazed version with low toxicity level. This gives an opportunity for the model to distiguish from the overall meaning of the text and concentrate on decreasing the level of toxicity (dirung the training process). That is why the data that is provided for you has the pair structure. Dataset structure is described in next section.
#
# ## Data Description
#
# The dataset is a subset of the ParaNMT corpus (50M sentence pairs). The filtered ParaNMT-detox corpus (500K sentence pairs) can be downloaded from [here](https://github.com/skoltech-nlp/detox/releases/download/emnlp2021/filtered_paranmt.zip). This is the main dataset for the assignment detoxification task.
#
# The data is given in the `.tsv` format, means columns are separated by `\t` symbol.
#
# | Column | Type | Discription |
# | ----- | ------- | ---------- |
# | reference | str | First item from the pair |
# | ref_tox | float | toxicity level of reference text |
# | translation | str | Second item from the pair - paraphrazed version of the reference|
# | trn_tox | float | toxicity level of translation text |
# | similarity | float | cosine similarity of the texts |
# | lenght_diff | float | relative length difference between texts |
#
# ## Evaluation criterias
#
# This assignment is on creating the solution, not on evaluating your algorithm. Major part of the grade will be dedicated to the structure of the solution, your development choices and your explonation on how you approached the problem.
#
# Submission should be a link to GitHub repository. It should be open repository, so that the course team could assess it easily.
#
# The structure of the repository should has the following structure:
#
# ```
# text-detoxification
# ├── README.md # The top-level README
# │
# ├── data
# │   ├── external # Data from third party sources
# │   ├── interim  # Intermediate data that has been transformed.
# │   └── raw      # The original, immutable data
# │
# ├── models       # Trained and serialized models, final checkpoints
# │
# ├── notebooks    #  Jupyter notebooks. Naming convention is a number (for ordering),
# │                   and a short delimited description, e.g.
# │                   "1.0-initial-data-exporation.ipynb"
# │
# ├── references   # Data dictionaries, manuals, and all other explanatory materials.
# │
# ├── reports      # Generated analysis as HTML, PDF, LaTeX, etc.
# │   └── figures  # Generated graphics and figures to be used in reporting
# │
# ├── requirements.txt # The requirements file for reproducing the analysis environment, e.g.
# │                      generated with pip freeze › requirements. txt'
# └── src                 # Source code for use in this assignment
#     │
#     ├── data            # Scripts to download or generate data
#     │   └── make_dataset.py
#     │
#     ├── models          # Scripts to train models and then use trained models to make predictions
#     │   ├── predict_model.py
#     │   └── train_model.py
#     │
#     └── visualization   # Scripts to create exploratory and results oriented visualizations
#         └── visualize.py
# ```
#
#
# In the top `README.md` file put your name, email and group number. Additionaly, put basic commands how to use your repository. How to transform data, train model and make a predictions.
#
# In the `reports` directory create at least two report about your work. In the **first report**, describe your path in solution creation process. List any architectures, ideas, problems and data that leads to your final solution. In the **second report**, describe your final solution.
#
# In the `notebooks` directory put at least two notebooks. **First notebook** should contain your initial data exploration and basic ideas behind data preprocessing. **Second notebook** should contain information about final solution training and visualization.
#
# In the `src` directory you should put all the code that is used for the final solution. Provide the script for creation intermediate data in `src/data/`. Provide `train` and `prediction` scripts in `src/models`. Provide visualization script in `src/visualization/`.
#
# ## Grading criterias
#
# Full assignment without any problems is said to be the `100%` solution.
#
# | Criteria | Weight (%) | Comment |
# | ---- | ----- | ----- |
# | Structure and code quality | 25 | Code quality, structure, comments, clean repo, commit history, reproducibility (manual seeding) |
# | Visualization, notebooks quality | 10 | Jupyter notebooks, visualizations |
# | Solution building | 40 |  Solution exploration, references, ideas decription, final report structure |
# | Final score, evaluation  | 15 | Evaluation function, final score, quality of results |
# | Usability, documentation | 10 | Docstrings, arguments parsing, README |
#
# If **PMLDL Course Team** will have any questions about your assignment or your work fails to show your results you will be called solution defence procedure.
#
# ## Report Examples
# ### Solution Bulding Report Example
#
# ```
# # Baseline: Dictionary based
# ...
# # Hypothesis 1: Custom embeddings
# ...
# # Hypothesis 2: More rnn layers
# ...
# # Hypothesis 3: Pretrained embeddings
# ...
# # Results
# ...
# ```
#
# ### Final Solution Report Example
#
# ```
# # Introduction
# ...
# # Data analysis
# ...
# # Model Specification
# ...
# # Training Process
# ...
# # Evaluation
# ...
# # Results
# ...
# ```
#
# **Good luck! Have fun!**

# %% [markdown]
# # Evaluating the Deletion model

# %%
import pandas as pd
import sys
sys.path.append(r'../src')
from models.deletion_model import DeletionModel
from metric.style_trasnfer_accuracy import StyleTransferAccuracy

# %%
test_data = pd.read_csv(r'/content/drive/MyDrive/University/PML/A1/Data/testing.csv')

# %%
bad_words_path = r"/content/drive/MyDrive/University/PML/A1/Data/bad-words.csv"
model = DeletionModel(bad_words_path)
x = test_data['toxic'].tolist()

output = model.detoxify(x)
output
# Out:
# ["call out your butchers and I'll tell you.",
#  'Who the has been going through my stuff?!',
#  'he can still die.',
#  "Yeah, that's the fucker's name.",
#  "I would take you on my shoulders, like, I'd strap you up, and I'd be like, let's go through hell.",
#  "shut up, I'm trying to drive.",
#  "I thought you were gonna hit him, but he didn't you up.",
#  'Too selfish and weak to carry out his own plan? No.',
#  'My wife will chew me out.',
#  "If you make me cross, boy, I'll detonate it, up it will go.",
#  "People don't usually talk to me like that, OK? Close your mouth, man.",
#  'murder.',
#  'what the fuck...',
#  "We can all rest now that the architect of that slaughter's been himself.",
#  'I was you, and you were me, and Kurt was Finn, and he wanted to have with me, as you.',
#  "Ugh, you're so boring.",
#  'If you spend the night making him miserable... ...I’m going home.',
#  "he's just gonna take my kidney out.",
#  "I'm sorry for screwing you.",
#  "ln five minutes, I'll tear that building down.",
#  'What? Kristina, I am so for you.',
#  'My God, we used to make fun of guys who bought like this.',
#  "you know... if you were smart, you'd have left three months to be, waited for it to calm down, got there quietly, in the middle of the night, and Constantin's temple, I could see that, but you're making a big show of it, and it's as dangerous as stupid.",
#  'you owe me something, robot head.',
#  'you my men and fooled my horses, and now... I have to punish you!',
#  "that would make the team's losers more fun.",
#  'what if you had taken me... and I would have had to you?',
#  'what the is going on?',
#  "She's related to Trinity.",
#  "I'm not going to Gillian's!",
#  '"Damn the child!" he thought as he opened the door, but he turned again to see whether the child was asleep.',
#  "but now, I don't care what your father is a cop or a killer.",
#  "but the horse, he'll kick you, only if you hurt him.",
#  'I was thinking of a convict out there on a gloomy, cold-hearted, low-fat bastard.',
#  "I don't want to see you. Can you pull your together, please?",
#  'oh, shit.',
#  "I don't know shit, man. I swear.",
#  'I screwed one woman when I was 19.',
#  "I'm Going to inject you withAllium sativum-- garlic.",
#  "But if it isn't, then her confession was a calculated lie, designed to cover her ass, because she knew a would look worse.",
#  'I have never... had before.',
#  "They're all male, they're all huge and they sit there and watch... ...with their tongues hanging out while I work on her.",
#  'this loud claim to be the first to extricate a fool from a deplorable community with a convict who separates an innocent of no-wit from "guilt is the age of positivity without respite for more than half a century.',
#  'And I would never with her head like that.',
#  "The Lord's stood enough of our nonsense, brethren; that's the plain truth.",
#  'he wants to be recognized as the perfect you have trained.',
#  "it's a wedding.",
#  'the battered hoof of seven men threw stones from the rocks.',
#  'Yeah, waving the around?',
#  'I got into a with his daughter.',
#  "I cover lrv Abel's for a living.",
#  "just because he's a man in prison doesn't mean he's an idiot.",
#  'Daddy cut him off with a slap in the hand.',
#  'Get round to his house, get the keys off him, get back here as quick as you can.',
#  'Why should I you? Take me to my friend, it!',
#  'The dutiful wife gets tired of your hours... and your lack of emotional intelligence.',
#  "let's see who will laugh for the last time, monkey.",
#  "That joy ride, I grant you, was a silly stunt but you got her back, didn't you?",
#  'To her?',
#  'This is our combined trash for a week.',
#  'if we ditch the mentally ill, if we send them home untreated, their will eventually catch up.',
#  'No, some goon with a stocking pulled over his face.',
#  "Why don't you off and be one then?",
#  'Get the out.',
#  "♪ A boy like that who'd your brother ♪ ♪ Forget that boy and find another ♪ ♪ One of your own kind ♪ ♪ Stick to your own kind. ♪ (laughing)",
#  "You took all his and you didn't even get to take his name.",
#  "Damn His Grace's pride.",
#  "God, you're such a fag.",
#  'First time I shot a gun, the kickback knocked me on my ass.',
#  'Stop this madman!',
#  'one of them is gonna push in as many countries as you can.',
#  "You're like a freakin' one-woman circus, Andie.",
#  'I the bastard!',
#  'Both of you, back in the yard now.',
#  'What the would I see in you, man?',
#  '"you damned breed!"',
#  'I went to shit, you know, and I... It was weird.',
#  'Shove off, Malfoy.',
#  "because they just don't want the shit.",
#  'my daughter is crazy.',
#  "Miles knew Tung wasn't faking relaxation for morale effect; nobody could simulate such a disgusting snore.",
#  'The peace that ignores thee, thou corrupt.',
#  "Inside the center, my boys will be clean, and outside... ...they'd be surrounded by the same rotten and and criminals.",
#  "It'll show those fools who called me mad! Come!",
#  'the terrified receptionist obeyed him as a dangerous maniac and fled behind.',
#  'You him the whole timeyou were married to me?',
#  "But I can't do anything about your backside.",
#  "Eric told Ruth she'd get the end of that deal.",
#  'all your weapons will be melted.',
#  '"bloody hell!',
#  '"Five dead, 300 head rustled, pursue and Indians," stop.',
#  "She's not a whore!",
#  "yeah, dude, when I graduated, I promised myself I'd never set foot on this godforsaken place.",
#  "whenever he had some shit, he always freaked out with those who didn't.",
#  "I'll break her heart.",
#  'old and dirty.',
#  'let them be rich, filthy rich.',
#  "If you wanna see some kicked, why don't you throw on some jeans and skate to this.",
#  "whatever you've planned, he'll with you now, Roman.",
#  '"Bullshit," Jerry said.',
#  'This pathetic substitute?',
#  "I'm writing messages with my boyfriend.",
#  'he may not be alive and you will be able to work as slaves, but he may also you.',
#  'yeah, yet the was nice.',
#  "We've come to rescue our friend, you evil bag of bolts.",
#  "the reason you like doing like that is that you just don't focus on studying.",
#  "Hey, I know how we get the on Butters' chin.",
#  '"you\'ve just saved my life, boss," I said, staggering back.',
#  'You on drugs?',
#  'In the case of hickock and perry smith,',
#  '"I want my boobs," she told me. "My life wasn\'t full of passion, but you know how it is.',
#  "What's the matter with you people?",
#  "he was so at the poor fool that he'd completely forgotten about the son of a in the chair.",
#  'the rest of you will stick your head on the floor.',
#  "one more lie and I'll cut you up.",
#  "I don't know this crazy slang.",
#  'Is this The Young and the Stupid?',
#  'Wanna me, baby?',
#  "why the do you come to my house if you don't want to do anything?",
#  "if it wasn't for the punch in the face.",
#  "They tie men to stakes and light 'em on fire.",
#  'what kind of question is that?',
#  'by the way, I have a lecture on the detection of astrophysical anomalies just at this meeting of nutters.',
#  'yesterday, yesterday, I wanted to the car...... and someone was blocking my way.',
#  "If you make Sen cry, I won't like you anymore, Baba",
#  'The damned are trying to flee.',
#  'maverick, you stud, sleep with me and kick me off forever.',
#  'You do want to have with her, right?',
#  'Damon is currently trying to be a good man, so I need another friend.',
#  'Bouncer says around 9:25, he saw a guy around 50, white, medium height, practically carry some drunk-off-her-ass girl to his car.',
#  'his alien smell stinks.',
#  'Did anyone get over it?',
#  'One of the drow held just one now, with his dirk arm tucked in close to his side to stem the flow of blood from a curving scimitar gash.',
#  "I think you're a menace.",
#  "I've found a scoundrel in here, Jenny.",
#  'I knew from the outset that the whole idea with the Predictor was probably silly.',
#  'What kind of country are we living in, crazy-Stan?!',
#  'people think they see ghosts, they call these clowns, -',
#  "But he's not a gay-basher.",
#  "You shut up, or you'll get another fifteen.",
#  'which is rewarded with a plus / minus rainbow, for which there are three intense measures. That woman is crazy.',
#  'are you serious?',
#  "so you can play with your girlfriend while I'm a monster for a week?",
#  'I already kicked your now. You need to proceed to the nearest exit immediately."',
#  "The Dark Army hadn't been in Shadow Wood, which was now Darken Wood, but the traitor king and his men had been.",
#  "look, I don't believe I'm going to suggest this to you, but I think we figured out a way to get this crazy guy.",
#  'Are you listening to me?',
#  "something's up!",
#  "if you can't eat it, it's piss.",
#  'when I was three, I cut her up.',
#  'Wanker.',
#  'what if it slipped out, leaked, leaked the world, that I gave a lot to the losers?',
#  'I hate everybody.',
#  "piglet, we're really sorry.",
#  'I can control my',
#  'You know, in the old days... if a witch betrayed her coven... they would her.',
#  'thanks, dumbass!',
#  'Woodcock his mom.',
#  "Oswald's going to my when he finds that tanker empty, man.",
#  'Brobdingnagian monstrosity.',
#  'he even had in a bed his ex-wife shared with his new man.',
#  'You see his face? Scared Israeli son of bitch.',
#  '"you\'re really crazy!" He laughed.',
#  "Those men who hurt you, you could have them if you wanted, couldn't you?",
#  "the fact that you're using that movie to have fun with or the fact that it really worked.",
#  'What? To make another fucked-up plan?',
#  'before the commissioner gets him killed?',
#  "How insane is he to be called, 'Crazy Tiger'?",
#  'You want to get to the point?',
#  "those aren't ordinary hunters, they're trained killers.",
#  'she pressed against him from her hip to ankle, and I jerked her robe over my shoulder and revealed her dressing gown and revealed her breasts.',
#  'in his thoughts... I will cut his great bald head with his axe.',
#  'what the happened to you?',
#  'She always said, "A husband can\'t get far."',
#  'And that the Hutus were a separate race of ignorant peasants.',
#  'blinking airplanes -- typical sky junk.',
#  "See if we can't shake something loose from that big old brain of yours.",
#  'And he poops on people.',
#  "you're gonna have a heart right in the face.",
#  '"what a trick!"',
#  'like an animal who wants to curl up and alone.',
#  "What's the pumpkin?",
#  'The day you seared my flesh with the sign of the fornicator?',
#  "if I did, I'd only be a liar.",
#  "if I knew I'd get you to visit me, I'd have kicked my ribs a lot sooner.",
#  "if the creature me, I hope he doesn't make me a sandwich and he won't leave me in the fridge where he can get any kind of cancer.",
#  'Why You Suck has become the template for people asking themselves: is their partner wrong for them?',
#  'they are despots and dictators',
#  "So Brian threatens to report you for fraud, and suddenly, you can't wait for the poison to him.",
#  "Dammit, I'm gonna have one too.",
#  "mom thought we should stop and make sure you didn't act like a fool.",
#  "You never-- Damn it. You never ease off on somebody like that... not when there's money involved.",
#  "I don't know -- I got to tell you, I mean, that could've been something to make her want to herself.",
#  'Or this blade will slide into her prety neck before you can even move a step !',
#  'cuff him!',
#  'I punched him first.',
#  'Look, super freak, you wanna find your Kal-El buddy... ...you better start working on your communication skills.',
#  'come on, maggots!',
#  'Gopreach that to somebody else.',
#  'You want a broken head?',
#  "what the hell, Hank, why didn't you tell me about Frank McBain?",
#  'It\x92s just a bloody lump of sandstone.',
#  "I don't drink juice, sucker!",
#  'of course, sometimes they a man if he makes a mistake!',
#  'To an infidel, the Pope has said, is not murder.',
#  'I him, and with the help of the head guard, escaped.',
#  "'It's that part of an imbecile,' I said, 'that punishes and vilifies and makes war gladly.'",
#  'I want you to get that up on the radio.',
#  'I feel like a woman smuggler.',
#  'you were both crazy last night.',
#  'bullshit. Let me see.',
#  "You're not a creature of the night, Balt.",
#  "Man: I'm bleeding out!",
#  'You need two things to live in this business: your and your word.',
#  'Stockpiles are rapidly diminishing... ...and when they are gone, we must die.',
#  'What the is wrong with you, man?',
#  'the villagers thought he was a pervert and they took him here.',
#  "It's going down tonight, and I'm gonna nail his ass.",
#  "if you do that, I'm gonna stab you in 20 inches deep in my ear.",
#  'big Nothing, and he made a fool of you too!',
#  'shut up.',
#  'God him!',
#  "Suck it. You're gone.",
#  "she's too and screaming, 'cause she's cracked.",
#  "and I want to kiss you, but there's a fence between us.",
#  'Your father is very upset with you cavorting with and fringe elements.',
#  "isn't that the brain hormone that the monster is drinking?!",
#  'Then cut me loose.',
#  'Of course, I had some rich Jew lawyer chewing my ear off the whole way.',
#  'Whenever Hayley wants to have sex, I have to think about Francine.',
#  '"You\'d be nuts to even think about an alternative."',
#  'what the did you do to me?',
#  '"With my bare hands and my teeth I him," he said.',
#  'Don Kim gets his bullet, thanks to you, and Hong Kong gets a goat to take the fall.',
#  "Anything you have that's metal, throw it at them.",
#  "It's going to be a massacre.",
#  'Ass! ...Hold this.',
#  'she casually changed her underwear and said, "By the way, I hope the is properly recycled."',
#  'We just want you to go back to your own country',
#  'he scared the out of me.',
#  "But your dad's actually kind of cute. - Shut up.",
#  'Sxounds like a stripper.',
#  "He knows I don't careabout him when we're",
#  'kids, your mom has a tube in her throat.',
#  '"Wow, it is amazing how crazy I really am"?',
#  "Don't worry, Dad, I read your instructions. Stop yelling at me.",
#  'Call 1-800-NuBOOBS and get yourself some new this weekend.',
#  'Shit happens like that sometimes.',
#  'Hey, douche bag, how the we gonna play with no electricals?',
#  "instead of his rescue, you should hope he dies, because if they don't, cruise buses will be driving down the main street.",
#  'Also, kids say the darndest things.',
#  "Vulgar, filthy, loud, some of the best nights of my life, but I assume you didn't go through all this trouble on my account.",
#  "We're totally ignorant of ourselves",
#  'the suspect is obviously preparing a defense in mental illness.',
#  'get out of the way, it!',
#  "Want to know what you'il of?",
#  'The Knicks are the only ones getting screwed.',
#  '"I take you, my love. I hold your adorable breasts. I hold you against my body."',
#  'Every penny! Every penny, mom!',
#  'I him in 1 5 rounds.',
#  'the wait will me.',
#  'yes, and then his him.',
#  'still no vaginas, Dad?',
#  'what the does that mean?',
#  'the system indicated your two murders, as the rediscovery of a known as "The Pig."',
#  'Put the down.',
#  "Well, God it, let's get the out of here and go celebrate.",
#  "She's also been taken under the wing of monster bodyguard and acne-smitten troll, the Grub, who has trained and conditioned Witch Bitch in the weeks leading up to tonight's event.",
#  'I busted my to nail this guy, and now he gets to stay in a cushy mental hospital, talking about his feelings, instead of rotting in prison, busting rocks and building the cross-country railroad.',
#  "The Cyrgai wouldn't have needed protection from the sun the way their bastard offspring would have.",
#  'Do you think me foolish?',
#  'If I’m on my feet for more than a couple of hours at a time it feels like somebody took a long splinter and rammed it straight up my leg to my balls.',
#  'Can you believe that shit?',
#  'How many more gotta get killed?',
#  'This man Pie is lethal.”',
#  "it's obvious that she almost you last night.",
#  'and for those other superstitious rubbish, there would be some natural explanation.',
#  'Thats disgusting!',
#  'Throw him in the pit.',
#  '"I\'ve it up again and again, but if you\'ll give me one last chance, they\'ll be on your knees.',
#  'take this to the kitchen.',
#  "it's more like coming home to him.",
#  'he says Tony wants his mother too.',
#  'pamela anderson video linkin park power rangers mistic forse basshunter 2girls1cup jonas brothers enrique iglesias bb8 big brother scenes akon wwe kama sutra hanah montana amnesia ibiza',
#  '"so Jarek Lazarevich, if you try to warn the others, I\'ll squeeze your brains out of your heads so quickly, they\'ll fly to Patashoquy before you mess up.',
#  'I gave him morphine, but his body will it up soon.',
#  "We'll cut you here.",
#  "but you... you're just gonna gut him with a knife, right?",
#  'I want my soul back, moron!',
#  'At least you were offered a meal Unlike your sadistic dad...',
#  "That was a foolish idea ... wasn't it?",
#  "But that don't matter a damn.",
#  "I'm a crook!",
#  'kick his face, Brad!',
#  'I found his sorry in the parking lot yelling for help.',
#  "I'll up before you waste your precious breath.",
#  "You're calling me a bitch? No, don't you remember the last line of Godard's A bout de souffle?",
#  'finally, heaven will devour all sinners, eh?',
#  '"No," and kept on looking nasty.',
#  'look, the animal bully is here.',
#  'James. What are you doing to me with your big, fat, hard...?',
#  'Listen. just call a fuck.ing ambulance.',
#  'crazy anarchist, the of world order, I suppose.',
#  "You people can't me, so you.",
#  "Rats in a cage would've done it better.",
#  '"Day of the Moron"?',
#  'and how did you get so dirty? "',
#  'Sonia flushed and Katerina Ivanovna was suddenly crying and immediately added to her own address that she was "such a silly goose that her nerves couldn\'t stand any more, and that there should be a long way to go, so there should be tea."',
#  "What I'm saying is, she gotta get or she goes crazy.",
#  "Fuckin' four years later?",
#  'The US Botanic Garden falls under the supervision of the Architect of the Capitol. - Get away from me, perv.',
#  'Bastards! There is a reason I never voted for you.',
#  'Hence our lame-ass name--Gemini.',
#  'well, I remember how you hated it, you seemed blank, useless, meaningless and aimless.',
#  "Except you can't fuckin' breathe!",
#  'Because he was me on rent.',
#  "Bart, don't the monkey and eat.",
#  "Yeah, why don't you tell me about your homicidal geriatric?",
#  'Gun down, sir.',
#  '"Wha\' did she say to ye, yon witch?"',
#  'let it be my mask, or your blood, red will be the last...',
#  'What the do you care?',
#  "'It's a little late for you to become such a Christian!'",
#  "Sir it's your shot.",
#  'is that what you want to cut my finger off?',
#  "This really ain't the time to be playin' that bruce willis bullshit.",
#  'I heard a whopping behind me, and when I turned I could see the tank of a tank outside the window of a skinny, white, filthy, filthy cat behind the window.',
#  "If I get you'll never get your hands on all that beautiful money.",
#  "Gilda, he's a virtual primitive.",
#  "No, it's this darned corset.",
#  '"you\'re just a heap of cards!"',
#  'I know how the his mind works.',
#  'I was in Arezzo, looking for this cheese shop when... when I passed this young girl, seven or eight years old, selling these just off the road.',
#  'Stefan said we should her in the woods.',
#  "I'll shave him.",
#  "You're Italian like the Pope's a Jew.",
#  "Well, let's hope you never have to choose between digging up your grandmother and making a sandwich or starving to death, Jason.",
#  "I'd arrest you.",
#  'Ah, they may be liars, snapped Polly, in a passable imitation of Strappis yap, but theyre our liars!',
#  'I him up.',
#  'when he used to hire the Hudson sisters...... why did he hire this fumbling?',
#  'like his namesake him stupidly, but he did well... and done eight wives.',
#  'your back is like a sack of lan.',
#  'The vampire had come with a hundred of his friends to us.',
#  'Where the you been, man?',
#  "you'd better get a high mortgage on your neck.",
#  'A job?',
#  "Yeah, there's no trust 'cause you didn't trust me enough to tell me.",
#  'very sophisticated for a scoundrel.',
#  "You were miserable in New York City, and you'il be miserable in the sticks.",
#  '. . .from the to the knee.',
#  'The only way for the body to rid itself of the acetone is through urination.',
#  'I am so screwed, Carl.',
#  "you're being very sick, you know that?",
#  'shut it down!',
#  "we know he's dangerous, unpredictable, selfish.",
#  'Someone jumped on your car with their butt.',
#  "You'll your back again. -...five...",
#  'You want to me?',
#  "Baby, I had three days after a heart and I didn't die.",
#  'Of course, by then, I’il be seventy years old. A lot of the rest of you will probably be dead.',
#  'I want you to uP Madison Square Garden.',
#  'Paul Ballard has a brain for Echo.',
#  "The dirt. You're dirty.",
#  'you start to laugh every time someone says "penal colony."',
#  "Yeah, well, if you're gonna throw away most of your life on some sitcom, you might as well get a sweet house out of the deal, right?",
#  "So most likely scenario, someone bloody in the building... ...now he's back and raising hell.",
#  "I said I'm gonna hit.",
#  'Fucking crazy!',
#  'It was an sound. . . but it was also wonderful, compelling.',
#  'Red Velvet cake.',
#  'Scrawny with big stary blue eyes and a walk.',
#  'The is on the street.',
#  'I will die, or my enemies will die.',
#  'Get the out.',
#  'That Indian is gone!',
#  "Don't worry, the next guy who's coming out has a dove hidden up his asshole, so...",
#  "he's got a little piggy named Mr. Gordo loves the ice revamp, no irony, and he's trying to drag me to Lowell House for tonight.",
#  "It's not a real monkey, it's a dummy.",
#  'And I did like you, until you walked in here with that agenda and--',
#  "Jesus Christ, Charlie, you give me this whole song and dance... ...about how you're out of that shit, but you're not.",
#  'Now get your in the car.',
#  'Beat a guy into a coma with a baseball bat.',
#  'can I sign this with this red dick?',
#  "You know, she ain't pretty as she used to be... and she a whole lot more than she used to... but she white.",
#  'promise me all three of you will me like everyone else.',
#  'Aim at the target and shoot!',
#  'stop thinking about your father and your brothers and the whole ranch.',
#  "well, I'm gonna beat him.",
#  "damn, that's exactly why I chose you.",
#  'cut him out yourself, Major.',
#  'and you look like you should be in a cage.',
#  "'man, you think you really want to die, don't you?",
#  'you can just tap or sleep a monkey in a bed, or you might as well play cards with friends.',
#  "That's one of the reasons why it's so frigging haunted.",
#  'The only stench is coming from you.',
#  'I mean, people gotta see this shit.',
#  'men are so unstable, right?',
#  "we can't just march into her and put the in.",
#  "If that hadn't happened, they would have continued to see us as the man of East Asia!",
#  'Everybody know the poor always being over by the rich.',
#  "I can't believe standard practice means you don't make one single phone call to the person whose name is on the account.",
#  'look, Stephen, your mom told me about your mental health issues.',
#  "don't think I'm going to fall in love with you because you're an Amor.",
#  "Everything you're proud of will end up as trash.",
#  "I'm an asshole, but he's worse.",
#  'of which one of the princesses is acting like a buffoon.',
#  "You'll if you just stop.",
#  "DOC: I the fleas off a dog's back at 500 yards, Tannen... ...and it's pointed at your head!",
#  'You walk into their house, you steal, you at them.',
#  'Here, let me tie you up.',
#  "My boy came to your school 'cause they were going to him in the public school.",
#  'then the gods will forgive you when you lose your head.',
#  'sorry, Yeesha is the name of the old witch.',
#  "yeah it's not that, it's just... you hit some one with you fist like a cow boy, like...",
#  'either you join us or you die.',
#  'I hope he peacefully.',
#  "And you'd do well to remember that without my generosity... your pathetic little farm would cease to exist.",
#  "Arthur, you're such a philistine.",
#  'I do feel a fool. Quick, take it away before the giris get back.',
#  "Rich people's kids are always up.",
#  "if you wonder if I'd sleep with you if you weren't gay...",
#  'where the did you get that?',
#  'Shit! - Get out of the house!',
#  '"and Hassop will be long and underground.',
#  "he's a Frankie, a bad bastard.",
#  'Oz, where the did Oz get this number?',
#  'Take this back to his cage !',
#  'he can millions of people!',
#  'I have had just about enough for one day.',
#  'Was I going to call the cops and tell them that a guy wanted to my girlfriend and myself?',
#  "I'm sorry about being an idiot.",
#  "If life was fair, I'd have gotten a new bike for my birthday instead of that car.",
#  'No shit!',
#  'Do you know how and twisted that is?',
#  'What the were you doing with a gun?',
#  'Either way, his bullet was going to hit the courthouse wall.',
#  'That I had... (CHUCKLES)',
#  "That's the best wayto a rattler.",
#  "I'm working a fuckin' drop car!",
#  'Friends, my balls!',
#  '"Did you ever read the \'Black Pig\'?" asked the lieutenant.',
#  'I know a lot of who would for natural blonde hair.',
#  'Because you just wanted to say, "I\'m a model." You don\'t care about me at all.',
#  'okay, so he tried to you.',
#  'genetically mutated into a perfect criminal.',
#  "if you don't, I'll shoot.",
#  'what the happened to you?',
#  "if this thing blows up...... and I'm not gonna believe in Allaha, I'm going to hell?",
#  'Female victim. Cut up into pieces.',
#  'How will you save the world?',
#  "then I brought Anna here to help me, she's my shots.",
#  "I'd need a ball of bat and a pinch of sulfur.",
#  'Viviane will be damned upset.',
#  'hanah montana basshunter wwe pamela anderson video jonas brothers scenes bb8 big brother power rangers mistic forse 2girls1cup kama sutra amnesia ibiza akon enrique iglesias linkin park',
#  'when they have a false sense of security, they are careless and lazy.',
#  "you're not going to ask me if he called my father and told him I'd sent him a letter where it was worth - why don't you yourself and another one where it was - we're trapped? '",
#  'You know the money we spend in this fucking...',
#  'This is where the will be held.',
#  'Spartacus and his set upon a wagon not far from here recently.',
#  '"Robert, you get your on the first plane back to D.C. and tell your friend that his operation is going to in a basket.',
#  'Looks like some little scamp just earned the right to put the Vikings helmet on Baby Jesus.',
#  'Bore me to death.',
#  'Today, I suggest you let me strike the worst scoundrels off this list.',
#  'damn, come on, this is such a lousy view.',
#  "and you should your Russian, because your husband will soon find out that you're the one who set him up.",
#  "and all of this was filled with resignation, a dignity that would have been wiped out by any factual and pathetic option for Clara's husband.",
#  "Daria, I'm of you!",
#  "He's gotta kiss her.",
#  "Can I take a picture? No, you bloody can't.",
#  "I'm going to clobber you!",
#  "That's great, but I'm dealing with the most ridiculous job in history.",
#  'Her computer was on the bed and there were some papers spread over the worn yellow spread where a thousand people had lain and and farted and fought.',
#  'these soldiers couldn\'t be more incompetent, even if they tried to lose. "',
#  'What the fuck?',
#  "it's just men messing around and losing their minds.",
#  'what the is that?',
#  "don't try to think globally, or you'll be crazy.",
#  'What the have you done, Longstreet?',
#  'So...I guess we shouldskip all that other stuff and get straight down to the shagging.',
#  "Don't you touch that!",
#  'snatcher!',
#  'Okay, it.',
#  'I gave him three shots.',
#  "That's me... back before any ofthis crazy happened.",
#  "you'll give it to the council once I'm dead.",
#  "Let's get up.",
#  'You like cutting people up?',
#  'Probably more I that dog than the girl, huh?',
#  "I don't want to up.",
#  'and if she is a witch, then she will hardly speak.',
#  "it's sucking on us!",
#  "it's a party, and it's mainly about this dog.",
#  'And for once... ...I wish a guy would take a dump on my chest.',
#  'that son of a scared the out of me.',
#  'Oh, damn!',
#  'now the demon, but your horse falls into the swamp.',
#  '"to tell you the truth, we treated you like a dog.',
#  'Show us your cock.',
#  'he wanted to be very hard.',
#  "'Shut up! 'Shouted Captain Smollett.",
#  'what is he, a bum?',
#  "Here's to the best salvage crew in the business!",
#  'we think she should explode in about eight minutes.',
#  'The Poles have put a sword in our hands. Turn it on them.',
#  "I'm supposed to electrocute John Coffey in less than a week's time, but it was William Wharton who the Detterick girls.",
#  "But they don't have on me.",
#  "You tell anyone else... and I'll rip your mouth out.",
#  'in the end, he falls in love with an ugly tyrant named Harley.',
#  'everyone hates you.',
#  'Spare me the details.',
#  "No, it's not Sarah in the morgue.",
#  'this couple of can us.',
#  'use it and them both.',
#  'Keep your opinions to yourself.',
#  "Doctor, you came into this meeting knowing that you had nothing, but instead of just saying that like a man, you thought that you'd dazzle us with a lot of fancy talk and think that we were too to notice.",
#  "why the crazy woman doesn't bring Jack back in the same way",
#  'No, no, no, you are idiot… No you change of plans by us.',
#  'he wanted to get a and handle it with Tommie.',
#  'Crazy happens at Dinah Shore.',
#  'And why the would he sew her fingers back onto her hand,',
#  'I guess you wonder how a girl like me can find myself in this of a Nevada desert in a bloodied Winnebago and a one-armed guy.',
#  'did he the dog?',
#  "Did you think they'd give a about justice?",
#  'Big D., you saying you eat pussy?',
#  'You just want me to hang?',
#  'We just booked Howard Moses to Clearasil.',
#  'and the thug, Prince Walesky.',
#  'I wish...... to die.',
#  "What's taking that little brainiac so long?",
#  "But Maria's guests had bastardy in their souls... perjury... adultery---the Devil.",
#  'What the you doing sitting there in the dark, Starling?',
#  'now you die.',
#  "It's not true.",
#  '"Frankly, having the lunatics trying to use you as the \'fulcrum,\' as you put it, is a vast relief to me.',
#  'Pathetic or completely justified with an amazing mama like her?',
#  "If you can't keep your in your pants, I can't protect you!",
#  "If you think you can me, fish, you can't, ok?",
#  "Margarita's short stay under the willows was marked by one episode: there was a whistling in the air, and a body, obviously missing its mark, dropped into the water.",
#  'Lamar says maybe and robbery.',
#  'they need a bath and medicine for syphilis.',
#  'The only real cure is to find the original source of infection and it.',
#  'I have a bullet here.',
#  "They don't give a shit!",
#  'Dempsey will be sure to strangle us if he catches us getting caught.',
#  "Holy shit! ...My feet can't f ail me now ...",
#  "you're a bunch of losers!",
#  "No.I'll--I'll shut up!",
#  'Act like a professional, dammit!',
#  "Barranquilla and Padilla, I'm a",
#  'What the was that?',
#  "all right, if the main point is getting Timoton to the right school...... it's ridiculous to focus.",
#  'if you just throw him in the pan, you him.',
#  "You are gonna break that girl's heart.",
#  "no, we don't the baby.",
#  'Well, I bet you can play the out of that harmonica.',
#  "'Kiddo,' he said in that same wheezing voice, 'if you sold him that piece of shit, you ought to be ashamed of yourself.'",
#  'you can me now, or we can keep playing if you want.',
#  'Jessica has two bastard children with a musician.',
#  'why are Buddhists so cruel?',
#  "he's worse than a kid.",
#  'I hope that woman at the front desk gave you about it.',
#  "and for all the saints, don't cut it on the monkeys.",
#  'usually I only take the second when someone tries to me.',
#  'At normal speed it didn’t make much sense, but once I speeded it up, I had the sucker.”',
#  "we're gonna start from the beginning and we're gonna keep this life behind us.",
#  'so she should of this disease.',
#  "I'm sorry, I didn't mean to I've never had much tact.",
#  'this seemed very ludicrous; and we told him that his serious behaviour was already half of the whole shambles.',
#  'Frank, she-- - Shut up.',
#  "so you're really a truck fool.",
#  'You could start a baseball team With all the he has in his office.',
#  'This guy in the joint, crazy Rasta fuck, made grilled cheese on the radiator.',
#  'Why would she come down to the beach? Fuck!',
#  "you're afraid of a bunch of on your ass.",
#  'what are you, a pervert?',
#  'how about on target.',
#  'no way, you, let me stay.',
#  "mine's dirty, too.",
#  'Shit, is that gold?',
#  '(take your fido good dog take a shag)',
#  "I think it's time to put him out of his misery.",
#  "God, that's disgusting.",
#  'your father was worse than he would have thought.',
#  'Fuck it!',
#  'Goddamn it, what happened here?',
#  "This ain't none of your business!",
#  'Scauldron... I say we just blast those boulders off his wing.',
#  'How was the sex? Talia...',
#  "And I don't sit around in clubs taking from gangsters.",
#  "yes, she's crazy.",
#  'I sat unseeing, and sank into a universe of inertia, glided down an irresistible slope and identified myself with the dumb, fluid colossus; it was as if I had forgiven it everything, without the slightest effort of word or thought.',
#  'they will the bed of Bernie.',
#  "let's not ruin this with a lot of bullshit, okay?",
#  'remove her bone marrow.',
#  "All right, I'm gonna get up, when I'm gone you sit in this seat... ...under you is a key to a locker where your half million is... ...along with some product we're returning.",
#  'Foley, you old son of a gun!',
#  'You joke about her?',
#  'what do you want for Christmas, fart?',
#  'as Clancy said later, the second best thing to happen was that they were near a small hill.',
#  'James J. Braddock, the garbage man who stood in the soup line a year ago.',
#  'And give up my just-been-fucked look?',
#  'one sees him as a saint, and others would him as a heretic.',
#  "Tell her you're just around.",
#  'you got me into this shit.',
#  'Tommy and his brother have already sunk you, fool.',
#  "I'm gonna you.",
#  'People recognised me for a lot of years, and for a lot of different reasons. And I just want my audience to know that I will not abandon them to become the weatherman.',
#  'You needed other wizards to hate and despise.',
#  '"Human scum.',
#  'Was it only she wanted?',
#  "there's only 5, this 1 is basically useless.",
#  'Milky-White is dead!',
#  "I'm never doing this again!",
#  'Maybe someone did itto start a gang war and let all them motherfuckerskill each other so that wecould all be free.',
#  'And if you knew that and did it anyway, you and deserve to miss Nationals.',
#  "Can't wait to be a again.",
#  'You look ridiculous in those panties, dude.',
#  'Stupid - why should he be afraid - - he is afraid to tell you!',
#  'And the next day, she was arrested and by a squad.',
#  'you want to race me, fatass?',
#  "I'll put your head in this box.",
#  'if you go to Tian Lang province, you will suffer so much if you wish to be dead.',
#  'and sex.',
#  'he jumped up and yelled, "I\'m going to get you, you bloody mess!',
#  'Can I please talk to someone?',
#  'A few moments ago I wanted your head–but not now.',
#  'get the out of our neighborhood!',
#  'I could notwatch you and do nothing.',
#  'Burn and turn.',
#  "the Allied Secret Service's information center has great care about solving your problems.",
#  "he's crazy.",
#  "for God's sake, he tried to me!",
#  'yes, I want the earth shaking in the throes when the saint and the goose are burned together.',
#  'My friends were like, "What the you talking about?"',
#  "it's just that Jen is barely human.",
#  'Then what the are you complaining about?',
#  'damn, I\'m really glad you\'re here with us. "',
#  'I swear I believed that at least one night of my life, I could be that girl.',
#  "Closest I got to feeling wanted was from a girl... who made me go through her johns's pockets while they screwed.",
#  "If menstruation is a symptom of brain then I should be on chemo right now. That's ridiculous.",
#  'Get the out of here!',
#  "I don't like you hating yourself.",
#  'I have to eat what you do, God it!',
#  "We're just dirt.",
#  'Mr. Palmer is very sick.',
#  'a tattoo, a grin, and about the height of a hydrant?',
#  'besides the lunatics, we all want the same thing.',
#  "He's probably screwed and figures bluffing is his best bet.",
#  "Don't get silly after two drinks and start telling those shaggy wolf stories of yours.",
#  "dude, if he doesn't get back in the morning, he's dead.",
#  'fight... both.... between the body and soul is not necessary...',
#  'I just want to know why you sent me this disgusting email.',
#  'Call your high school girlfriend at 2:00 in the morning.',
#  'Mr. Scott, you old space wolf!',
#  'Her coat was still open, and he could feel the soft, maddening weight of her breasts.',
#  "You like to drink, you have a lot of around, you make music, you're good looking, you're lazy and you have a bad temper.",
#  'the dog-bitch landed right on the blade.',
#  '"I was tempted again and again to shut down the operation, but the pathetic ones would implore me, and so I continued.',
#  'Really? Because I remember a very interesting incident with some ladies, you and a garbage bag.',
#  "I hold him like this and I'll cut eight Yakuza members in 4 seconds.",
#  'intelligent loners.',
#  "If we don't get him to a doctor, he will die.",
#  'you arranged are in possession of the door, and a hand on a small',
#  'If he is, Arthur Delacroix is the unluckiest that ever lived.',
#  'A house? -',
#  'Oh, iPhones.',
#  "you're a good friend.",
#  "Hey dog, don't cry for thatmotherfucker because, WOW!",
#  'I can lay the world at her feet, dammit!',
#  'He would drop wastepaper baskets on your head, pull rugs from under your feet, pelt you with bits of chalk, or sneak up behind you, invisible, grab your nose, and screech, "GOT YOUR CONK!"',
#  'these Indians never give us peace.',
#  "Fuck. - You're gonna like it.",
#  "if I am - and I'm brilliant - I might just save the world or I'll rip him apart.",
#  'throw him out with the rest of the garbage.',
#  "I'm going to give my dad a piece of my liver.",
#  "Unh, that's for screwing my husband.",
#  'What if Dechee sent us here just so he could us.',
#  'Of you, of your selfishness, of your miserable ideals.',
#  "and right now, I'm sitting on top of one of your big, juicy tits.",
#  'Can he hear me?',
#  'The best shall be hung from these hooks.',
#  "first of all, you've got a from you, and second, astronomy is just a bunch of boring shit.",
#  'I was counting on you to do something to stop this whole ridiculous thing.',
#  'father of the year.',
#  "I came to tell you, that if you've had enough of making yourself ridiculous with your dolls and your verses, you can take them down now.",
#  'even my brother Bila?',
#  'you want to him?',
#  "You could've shut your mouth, cooked, and made as much money as you ever needed.",
#  'what if he had something to do with me?... what if he had something to do with me... maybe he was a ghost, or what...... the sheriff said he was a serial killer, so he shot him...... what the are you saying?!',
#  "And the one thing I learned is, you can't lie to a liar.",
#  'Shut your eyes, baby.',
#  'get out of my country.',
#  'will you listen to me?',
#  'They him, and you did nothing.',
#  'and anyone who claims the opposite, whoever he is, is a liar!',
#  'do you want me to go crazy?',
#  'get your hands off me.',
#  'There was a the size of a dime in the crotch, I remembered.',
#  "And when you have money, you don't have to hang out with any poorass loosers like you guys.",
#  'just Asians! ♪ A lanthanum and eight ♪ ♪ A asthma and radium... ♪',
#  "you clowns, you've got about two minutes to end this theater.",
#  '"That\'s a big Sucking guard detail for someone who\'s not going anywhere."',
#  "It's just like a piece of overcooked penne between his legs.",
#  'When the Monster reaches seventy he will',
#  'Some nutjob obssssed with the Candyman Miguel and that girl.',
#  "I don't ever want to see you again.",
#  'can the man control himself?',
#  'we will never so many men.',
#  "I'm better than half the losers that sign up.",
#  'You call him a all the time.',
#  "but he's a little foolish.",
#  "Pitt smoothly stepped through the cabin door, jammed the heel of his right foot into the guard's neck, bent down and snatched up his automatic rifle, a Bushmaster M17S, and clubbed him behind the neck with the end.",
#  "Hell, I was born here and I was raised here... ...and it, I'm going to here!",
#  'oh, shit!',
#  "I won't wait for them to me.",
#  'Yeah, but anti-inspector had a funny mustache and was kinda rapey.',
#  'throw him out.',
#  "OK, let's eliminate that demon.",
#  'I had a day.',
#  "I haven't been to The Hawk in over a year.",
#  'No, Logan is a repressed WASP and Max is a... a broken toy.',
#  "you're gonna slap me and then you want to apologize?",
#  'I hate Greek.',
#  'come on. Come on, wolf.',
#  "he patted Brin's shoulder, then inexplicably frowned at Ron as if it were his fault, and muttered something about the damned intruders.",
#  "I'll do this with the gun.",
#  'this ship sailed off with a photo of the and then bumped into Mr. Chainz.',
#  'he must be scared shitless.',
#  '"Stevie Wonder sees more than you do!"',
#  'Dad, is it true what Stock said, that when I make love... the woman will trap my inside her?',
#  'at this rate you could slow down a funeral.',
#  '"Gross," Teg agreed.',
#  "He's a serial killer.",
#  "you're smart, talented, but useless if you can't make the right choice.",
#  "in the end, even gully dwarves must have in this gods' damned land.",
#  'One of us have to get down to the car and get help.',
#  'They both had to be killed... ...because they were both in my way.',
#  'You kids have balls, I can use you.',
#  'I think that if the cop had shown up back here _ she would have come running to us, screaming bloody murder.',
#  'but I will admit that I am sometimes tremendously tired of men and what I call their baboon\'s demonstration of masculinity. "',
#  'Sex in the Batmobile; and Wolveriskey.',
#  'The problem was that Grunwalski, whod gone further away, behind a bush, hadnt finished his shit.',
#  'she has your eyes and my hairy legs.',
#  'Remember when I said that Athena got leg-fucked by Hephaestus?"',
#  "hell, I'm gonna throw you a couple of painkillers for your ride home.",
#  "my dad's a grifter.",
#  "Personal, I ain't give a good what you believe or don't believe!",
#  "I want $50,000, or I'll tell the whole world that Arthur Mitchell, family man, schoolteacher, deacon, is a pedophile.",
#  "Promise you won't mention that orgasmic superman again.",
#  "the judgment, whatever he's like.",
#  'I\'m of this paranoid "My wife is cheating around on me" bullshit.',
#  "So now it's out o' yer system go home to that girl o' yours and start some bloody living.",
#  "But even have a jerk as a younger brother is better than I don't have one at all.",
#  'the... same... Italian killer.',
#  'I want to see that town destroyed.',
#  'from Texas there are only spikes and fags, Private Cowboy!',
#  "I'm going to do not clean up.",
#  "Frostbite's Not Too Bad But I Gotta Fix your Artery Now.",
#  'Joey was a keener and an idiot, but nothing happened between us.',
#  "Didn't like that Griggs trying to prove otherwise.",
#  'Let\'s look up "blowjob." Here it is.',
#  'what the are you talking about?',
#  "The pig doesn't get in.",
#  'What the did you do, Angel?',
#  'By now Julia was clearly delirious, babbling nonsense.',
#  'You want a spanking like Uncle Bill gave you last night?',
#  "He's full of explosive putty.",
#  'take your-right attitude and shove it up your ass.',
#  '"Bullshit," Lindsey said sharply.',
#  'he punched me in the chest.',
#  "you're gonna drown her?",
#  "White: You're a fool to be fun to go with, I have to say.",
#  "you'll never see me that risk for a white like you did.",
#  "That's a lie! - You became a member of the Kremlin Club.",
#  '"Do glitbitcrs spice?"',
#  'How does she even know who the we are?',
#  'You are just incapable of trust.',
#  'just one bomb.',
#  "That woman mustn't die.",
#  "maybe he's keeping it just 'cause he's got the pleasure of sucking his life out of them.",
#  'many times, white men come and take the warriors, many young men like slaves.',
#  'and the savages will make soup bowls out of our skulls.',
#  'his throat was decorated with a ribbon of raffle, and the foul content was secured with a cork-stopper.',
#  'Kohl was their informants.',
#  'this is ridiculous.',
#  "it's a game for an idiot, right?",
#  'No way did a quick bite and leave her clean like that.',
#  'Gabe keeps his mouth shut.',
#  'why the am I always so smart?',
#  'every night I prayed to die.',
#  'Went over, like, "Do you want a picture?',
#  "They call me fuckin' Quicks, man.",
#  'hey, you troublemaker.',
#  "Yeah. Some loses his shirt, so he to the General. That's it.",
#  "I don't give a about her.",
#  'Are you gay?',
#  "and as the opponent's sped past me so quickly and so thickly, it was my little place to sit and return to our citadel.",
#  "'Damn!' she said.",
#  'I figured you should have fresh breath while Meat Hammer turns your inside out.',
#  'here, lie down and shut up.',
#  "Sorry. You know, I could tell you you ain't seen in no Hollywood movie before.",
#  "We'll go step by step... ...and cut off every bulkhead... ...and every vent... ...until we have it cornered, and then we'll it... ...the out into space.",
#  "he wants 50% of the market for that list, and he's such an asshole.",
#  'To the Gate, you slugs!',
#  "I'm just saying, like, you know, they just lie there and themselves, right?",
#  "She can't me. She's dead.",
#  'what would happen if he baked my shit?',
#  "you're a weirdo.",
#  "People who weren't sure what to think of NASCAR or more sure today after a NASCAR driver released bigoted and ignorant statements on his podcast.",
#  "are you an animal and you don't understand human language?",
#  'Paulie was gonna stab me in the face.',
#  "you're going to die?",
#  "I think he's a liar.",
#  "That's my mum!",
#  "you don't look like a fool.",
#  "All who stay here will die, and I have seen too much of lately.'",
#  'First thing they did. You know, they see I pay a big money bond for my boy... they start thinking that "where there\'s smoke there\'s fire" logic.',
#  "you're a flytrap.",
#  'he was there by his car...... and he sucked on his clothes...... and he kept it under his nose.',
#  'Yeah, totally and totally idiotic.',
#  'Yes, yes!',
#  'No, I had in high school.',
#  "that's the basic rule of porn, you have to be sweaty.",
#  'We have for the first time in years... - And this is the first thought to cross your mind?',
#  "let's say a pound-for-a-hand handshake, between me and the of yours...",
#  "I don't really give a rat's what you think of us, but if we're gonna bring down this spirit, we need to find the remains, salt them, and them into dust.",
#  "he's the devil, the in the heavens.",
#  'I just... ...killed it by being what I hate:',
#  'would you mind telling me what the is going on?',
#  'He is worse than a man, Khan Baba.',
#  "I don't want to understand it. - You're dead!",
#  'Go get help, man!',
#  'I picked up the and started at them.',
#  'When we get backto Washington, you morons are through!',
#  "I've never experienced an adrenaline rush since I a Missouri senator from Missouri in the conference room.",
#  "You're the one who's weak.",
#  "First you're obsessed with baseball fights then you need to play war crap, then you've got to be a celebrity chef.",
#  'I would have kicked them instead of helping them.',
#  'the idea of how Ferengi seduces the lady of the house is... disgusting.',
#  'This is your partner in crime, this little freak?',
#  'then why did you marry that midget?',
#  '"tell him," he snorted, and went to his wife\'s hometown, "is your mother selling your filthy body to the driver of vaco?"',
#  'The good news is that your father is too valuable for us to kill.',
#  "You're saying that Mr. Blonde... was gonna you... and then when we got back he was gonna us... take the diamonds and scram.",
#  'Rats, dear madam, are inevitable guests',
#  'You want me to go get beat up?',
#  "That nigga's enemies got enemies.",
#  'What kind of is that?',
#  'good.',
#  "God, you're a menace.",
#  "He's not as bad as that Dutch fellow with his gods being astronauts rubbish, but Mark isn't a rigorous researcher either.",
#  'oh, shit.',
#  'usually journalists, but sometimes bounty hunters, lunatics with guns.',
#  "wow, you don't know about the suburbs.",
#  'Is that so hard to understand?',
#  'he went as if he was sucking on his suffering and ignoring the huge weight, he went as if he could not give up, as if denying his skills.',
#  'No, for there were other, better things to do with men such as Fess Ferenc and Arkis Leperson than them.',
#  'what are you doing with that clown?',
#  'Why would you be telling him?',
#  "Just the who's still waiting for the return on her Internet investment.",
#  'They either worship him or hate his guts.',
#  'With the cash and the name of the guy to kill.',
#  "Let's go the out of this stock.",
#  'You make me crazy, you know that?',
#  "I love you, Wally, so don't make me kick your butt.",
#  'But he was already black.',
#  "don't hit me in the face.",
#  "Damn, Davis, I'ma tell you when I'm ready.",
#  'Bang your head ...of the Middle East,the Ayatollah!',
#  'They smell like pigeons!',
#  "and then I'll spray him around his hands and feet...",
#  "Tell your mom that's what she gets for messing with Raymond Tubbs.",
#  '"Wipe this present-day Sodom and Gomorrah off the face of the earth."',
#  'hug your foster mother!',
#  'You know how you told Sasha not to have with me for six months?',
#  'he massacred the entire village.',
#  'as soon as any of you bring a into the upper body, shoulders, chest or arms, the others must escape.',
#  'Quick, a miracle, you swindler',
#  "Evil - you're all evil again.",
#  'Shut up, all of yous!',
#  "we're gonna take his kimono, what we've got, and we're gonna hang him...",
#  'Tell me why these clowns have and casinos make 20 million a year?',
#  'Get me a tourniquet before I bleed to death.',
#  "So you're telling me, that they built this big arena, and then came and got us just for us to fight?",
#  "I'm a junkie with a monkey.",
#  'you think they miss our hot asses?',
#  'how the did they get here so fast?',
#  'my grandma always said...... "Why buy a cow if you have a free sex?"',
#  "tell him there's another attempt at and we need him.",
#  "Just keep that in mind while you're trying to save his sorry ass.",
#  'we live in a silly, commercial world, with no and confidence.',
#  'the gentle, almost timid beat of the clown from the front of his desk interrupted his reasoning.',
#  "They're private military, killers for hire.",
#  'pathetic in what way?',
#  'How much do I need to shave between the cheeks?',
#  'Good or bad, this thing people.',
#  "I just don't really like downed T-shirts and boys in shorts under my butt.",
#  'those guys got a lousy memory.',
#  'Shut up.',
#  'You went to camp?',
#  'you think you can pull the off and before any of us do it?',
#  'You got the wrong end.',
#  'Drop the piece, turn the around.',
#  "We come to college, we get blown off by chicks for midgets, and you're hanging out with a sorority girl?",
#  'but walls, gentlemen, walls are just pathetic, for which it is only soft, poor earth, for centuries our old, good rippling with the Mississippi, on its way to an alula canvas, only the ground.',
#  "I wrote to management two weeks ago about these friggin' bumpers.",
#  'Any man who can create this chamber of electronic marvels... ...would be able to devise a machine to stab him in the back 1 2 times.',
#  "Mia's in some fucked-up situation with her teacher.",
#  'wait; did you take her to a motel and all you had was a in your ear?',
#  'When they got to the car it was just a blackened hulk.',
#  'Get off. Richard, I bet my son could kick the out of both your kids... ...blindfolded, one hand tied behind his back.',
#  'I mean, thank God we live in a country where you can film bears having with humans, huh?',
#  "Why you always bustin' my ass, Rafe? Which way you goin'?",
#  'Kill! Who was that?',
#  'Smith, remember when we met and you went off to law school, We rolled around with other people And occasionally had mediocre phone sex?',
#  "'i him, 'said Shannow.",
#  "you're gonna be sick.",
#  'one was about to hang himself over the door (assaulting him in the first row of a typewriter), what would fall on her head when she opened it, so it would either her or at least stun her.',
#  'But also vain and selfish.',
#  'The spear fell from his nerveless fingers as a sword punctured him from behind.',
#  'You mind telling me what the that was all about?',
#  'Insolent! - Insolent!',
#  "he's a wreck.",
#  "because what's so special about your bad flirting with that woman today, how Marty described it, correct me if I'm mistaken...... is that you were talking about her bitches, like your ex-wife's doppelgangers.",
#  'what a great song.',
#  'God it! Stop!',
#  "Kadaj's gang is young and brutal.",
#  'Is that about you two getting your on? Look.',
#  "I'm not trying to you.",
#  'Cam, he was every bit the you were.',
#  'Fail,... ..and you will perish without trace.',
#  "you're gonna dump 20 grand for any fool in this team?",
#  'The fool booked a long ride, huh?',
#  'At some pointyou feel like the bitch.',
#  'Where are you going, pussy?',
#  'Your boss found out -- you shot him.',
#  'If you want to anyone... your executioner.',
#  "It's all right!",
#  "And his brother's even more powerful scum.",
#  "I'll cover your because it's my too.",
#  "you didn't ask who you were supposed to kill.",
#  "Problem is, I don't fuckin' believe you.",
#  'I had no idea you would for me.',
#  '"I know it sounds weird," she said, "but I\'m dying for a cigarette, and this is the only place in this building where I can keep one of them on fire.',
#  'You sit there like a retard.',
#  'Feel it, Troy. Throw it!',
#  "One minute, your best friend, the next, you're a leper,",
#  'big scary vampire went to the sun to fry.',
#  'Quit your and keep trying to untie me.',
#  'Of course, the government’s reduction of community policing in favor of paramilitary forces stationed in quasi-military barracks, and the Minister of Interior’s description of the young rioters as “scum” who should be washed away with an industrial power hose, has not helped.',
#  'He screwed us.',
#  "and somewhere underneath, they're narcs.",
#  'Look, her heart was weak, her nervous system was fried.',
#  "Yes, I'd like to kiss you.",
#  "But if I fail... I'll get another white dog... and another, or another, or another, and another... and keep on working till I lick it.",
#  'Tell him thank you… And to go himself.',
#  'How to send them off to in some foreign land?',
#  'You have any idea how many guys in the room wanna nail your wife right now?',
#  "That's 4 for staying together 3 against, and one kind of gay.",
#  "Who's the best on the East Coast?",
#  'hop in, shooter.',
#  'who the is that?',
#  "It's a milligram of sweetener.",
#  "hey, Cartman, he says you're transgender.",
#  '”Black apples,” he says.',
#  'Why, there you are, my little muffin.',
#  "(Click) Ugh. Where'd you hear all that junk?",
#  "I know you don't want to hear it, but they're gonna him anyway.",
#  "So you're giving me about my parenting skills, and some total stranger is off with... he's not a total stranger.",
#  'I mean, Leia, right, she looked like she was crazy... but I could have said she liked me.',
#  "Yes, you fuckin' are.",
#  "it's a bathroom for which you would kill.",
#  "You don't know how many people he sucked... ...over the last however many centuries he's been alive.",
#  'Now tickle me under the chin, mistress.',
#  "I'm gonna put my next rib in your lungs.",
#  'Do your smell like perfume?',
#  "you lie again, and I'll gouge your eye out.",
#  'what the is wrong with him?',
#  'Where the do you keep your gun?',
#  "I'm a jerk on the bench and you're walking around me, but this time, after I've offended you, you'll come back and give me what I want.",
#  'Better to be a king in hell... than a in heaven, kid.',
#  'I screwed up.',
#  'oh, you want me to beat someone to death?',
#  'shit, I grew up with them.',
#  "if we follow orders, we're dead!",
#  "Told you wouldn't him.",
#  'I\'m not that stupid, Paul. "',
#  'your uncle drives people nuts, okay?',
#  "we don't come to terms with the treacherous and damned Sauron.",
#  "Ferguson's sausage... the only good that came out of these miserable countries.",
#  "It's Anita Blake, the vampire executioner.",
#  "they're all our favorite killers.",
#  "then he wouldn't be able to see him again, and if he wasted that last chance to get a good look at him, he'd be around the past, so he's a fool.",
#  'UN is after your ass.',
#  "You let him do this to me, and you'll be more evil than mara could ever be.",
#  "That's ridiculous.",
#  "I'm thinking about what the it is.",
#  'Jamie, stop sulking like a baby!',
#  'you can cut someone with him.',
#  ...]

# %%
# from metric.style_trasnfer_accuracy import StyleTransferAccuracy
sta = StyleTransferAccuracy()

accuracies = sta.classify_preds(64, output)
# Out:
# Some weights of the model checkpoint at SkolkovoInstitute/roberta_toxicity_classifier were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Calculating style of predictions
# 100%|██████████| 1806/1806 [04:57<00:00,  6.07it/s]

# %% [markdown]
# ### Calculating the average style transfer accuracy for the deletion model

# %%
import numpy as np

np.mean(accuracies)
# Out:
# 0.4817837239087542

# %% [markdown]
# ## Calculating cos similarity

# %%
output[1]
# Out:
# 'Who the has been going through my stuff?!'

# %%
len(x)
# Out:
# 115556

# %%
x_reduced = x[:10000]
output_reduced = output[:10000]

# %%
from metric.cosine_similarities import CosSimilarity

cos_similarity_calc = CosSimilarity()
cosine_similarities = cos_similarity_calc.calculate_cosine_similarity(x_reduced, output_reduced, batch_size=64)

# Calculate the mean cosine similarity
mean_similarity = np.mean(cosine_similarities)
print(f"Mean Cosine Similarity: {mean_similarity}")
# Out:
# Mean Cosine Similarity: 0.981300950050354
